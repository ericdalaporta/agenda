# %%
import os
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'rest.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
from django.db import connection, reset_queries
import time
tempo_inicio = time.time()
produtos = Produto.objects.all().select_related('fornecedor')
for p in produtos:
    nome_fornecedor = p.fornecedor.nome
tempo_fim = time.time()
duracao = tempo_fim - tempo_inicio
print(f'Executou {len(connection.queries)} consultas')
print(f' Tempo de execução: {round(duracao, 3)} segundos')
reset_queries()
# Out:
# Executou 1 consultas
#  Tempo de execução: 0.001 segundos

# %%
print(produtos.query)
# Out:
# SELECT "produtos_produto"."id", "produtos_produto"."nome", "produtos_produto"."preco", "produtos_produto"."quantidade", "produtos_produto"."fornecedor_id", "fornecedores_fornecedor"."id", "fornecedores_fornecedor"."nome", "fornecedores_fornecedor"."cnpj", "fornecedores_fornecedor"."fone" FROM "produtos_produto" INNER JOIN "fornecedores_fornecedor" ON ("produtos_produto"."fornecedor_id" = "fornecedores_fornecedor"."id") ORDER BY UPPER("produtos_produto"."nome") ASC

# %%
import os
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'rest.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
from django.db import connection, reset_queries
import time
tempo_inicio = time.time()
produtos = Produto.objects.all().select_related('fornecedor').defer('fornecedor__cnpj')
for p in produtos:
    nome_fornecedor = p.fornecedor.nome
tempo_fim = time.time()
duracao = tempo_fim - tempo_inicio
print(f'Executou {len(connection.queries)} consultas')
print(f' Tempo de execução: {round(duracao, 3)} segundos')
reset_queries()
# Out:
# Executou 1 consultas
#  Tempo de execução: 0.001 segundos

# %%
print(produtos.query)
# Out:
# SELECT "produtos_produto"."id", "produtos_produto"."nome", "produtos_produto"."preco", "produtos_produto"."quantidade", "produtos_produto"."fornecedor_id", "fornecedores_fornecedor"."id", "fornecedores_fornecedor"."nome", "fornecedores_fornecedor"."fone" FROM "produtos_produto" INNER JOIN "fornecedores_fornecedor" ON ("produtos_produto"."fornecedor_id" = "fornecedores_fornecedor"."id") ORDER BY UPPER("produtos_produto"."nome") ASC

# %%
import os
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'rest.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
from django.db import connection, reset_queries
import time
tempo_inicio = time.time()
produtos = Produto.objects.all().select_related('fornecedor').only('fornecedor__cnpj')
for p in produtos:
    nome_fornecedor = p.fornecedor.nome
tempo_fim = time.time()
duracao = tempo_fim - tempo_inicio
print(f'Executou {len(connection.queries)} consultas')
print(f' Tempo de execução: {round(duracao, 3)} segundos')
reset_queries()
# Out:
# Executou 1 consultas
#  Tempo de execução: 0.001 segundos

# %%
print(produtos.query)
# Out:
# SELECT "produtos_produto"."id", "produtos_produto"."fornecedor_id", "fornecedores_fornecedor"."id", "fornecedores_fornecedor"."cnpj" FROM "produtos_produto" INNER JOIN "fornecedores_fornecedor" ON ("produtos_produto"."fornecedor_id" = "fornecedores_fornecedor"."id") ORDER BY UPPER("produtos_produto"."nome") ASC

# %%
import os
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'rest.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
from django.db import connection, reset_queries
import time
tempo_inicio = time.time()
servicos = Servico.objects.all()
for s in servicos:
    lista_produtos = [p.nome for p in s.produtos.all()]
    print(f"Serviço: {s.nome} - Produtos: {lista_produtos}")
tempo_fim = time.time()
duracao = tempo_fim - tempo_inicio
print(f'Executou {len(connection.queries)} consultas')
print(f'Tempo de execução: {round(duracao, 3)} segundos')
reset_queries()
# Out:
# Executou 1 consultas
# Tempo de execução: 0.001 segundos

# %%
print(servicos.query)
# Out:
# SELECT "servicos_servico"."id", "servicos_servico"."nome", "servicos_servico"."preco", "servicos_servico"."descricao" FROM "servicos_servico" ORDER BY UPPER("servicos_servico"."nome") ASC

# %%
import os
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'rest.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
from django.db import connection, reset_queries
import time
tempo_inicio = time.time()
servicos = Servico.objects.prefetch_related('produtos').all()
for s in servicos:
    lista_produtos = [p.nome for p in s.produtos.all()]
    print(f"Serviço: {s.nome} - Produtos: {lista_produtos}")
tempo_fim = time.time()
duracao = tempo_fim - tempo_inicio
print(f'Executou {len(connection.queries)} consultas')
print(f'Tempo de execução: {round(duracao, 3)} segundos')
reset_queries()
# Out:
# Executou 1 consultas
# Tempo de execução: 0.001 segundos

# %%
print(servicos.query)
# Out:
# SELECT "servicos_servico"."id", "servicos_servico"."nome", "servicos_servico"."preco", "servicos_servico"."descricao" FROM "servicos_servico" ORDER BY UPPER("servicos_servico"."nome") ASC
